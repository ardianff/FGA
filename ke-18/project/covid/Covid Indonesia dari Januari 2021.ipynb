# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("covid_19_data.csv")

# %%
indonesia = df[df['Country/Region'] == "Indonesia"]
indonesia
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 3114      3115      03/02/2020            NaN      Indonesia
# 3258      3259      03/03/2020            NaN      Indonesia
# 3421      3422      03/04/2020            NaN      Indonesia
# 3590      3591      03/05/2020            NaN      Indonesia
# 3760      3761      03/06/2020            NaN      Indonesia
# ...        ...             ...            ...            ...
# 302674  302675      05/25/2021            NaN      Indonesia
# 303439  303440      05/26/2021            NaN      Indonesia
# 304204  304205      05/27/2021            NaN      Indonesia
# 304969  304970      05/28/2021            NaN      Indonesia
# 305734  305735      05/29/2021            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 3114    2020-03-02T18:03:04        2.0      0.0        0.0
# 3258    2020-03-02T18:03:04        2.0      0.0        0.0
# ...

# %%
kasus = indonesia[indonesia['Confirmed']>0]
kasus['ObservationDate'] = pd.to_datetime(kasus['ObservationDate'])
kasus
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 3114      3115      2020-03-02            NaN      Indonesia
# 3258      3259      2020-03-03            NaN      Indonesia
# 3421      3422      2020-03-04            NaN      Indonesia
# 3590      3591      2020-03-05            NaN      Indonesia
# 3760      3761      2020-03-06            NaN      Indonesia
# ...        ...             ...            ...            ...
# 302674  302675      2021-05-25            NaN      Indonesia
# 303439  303440      2021-05-26            NaN      Indonesia
# 304204  304205      2021-05-27            NaN      Indonesia
# 304969  304970      2021-05-28            NaN      Indonesia
# 305734  305735      2021-05-29            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 3114    2020-03-02T18:03:04        2.0      0.0        0.0
# 3258    2020-03-02T18:03:04        2.0      0.0        0.0
# ...

# %%
plt.plot(kasus.ObservationDate, kasus.Confirmed)
plt.xticks(rotation = 'vertical')
plt.show()

# %%
kasusjan = kasus[kasus.ObservationDate>='1/1/2021']
kasusjan
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 192536  192537      2021-01-01            NaN      Indonesia
# 193299  193300      2021-01-02            NaN      Indonesia
# 194062  194063      2021-01-03            NaN      Indonesia
# 194826  194827      2021-01-04            NaN      Indonesia
# 195590  195591      2021-01-05            NaN      Indonesia
# ...        ...             ...            ...            ...
# 302674  302675      2021-05-25            NaN      Indonesia
# 303439  303440      2021-05-26            NaN      Indonesia
# 304204  304205      2021-05-27            NaN      Indonesia
# 304969  304970      2021-05-28            NaN      Indonesia
# 305734  305735      2021-05-29            NaN      Indonesia
#
#                 Last Update  Confirmed   Deaths  Recovered
# 192536  2021-04-02 15:13:53   751270.0  22329.0   617936.0
# 193299  2021-04-02 15:13:53   758473.0  22555.0   625518.0
# ...

# %%
plt.plot(kasusjan.ObservationDate, kasusjan.Confirmed, color='blue')
plt.plot(kasusjan.ObservationDate,kasusjan.Recovered, color='green')
plt.plot(kasusjan.ObservationDate,kasusjan.Deaths, color='red')
plt.xticks(rotation = 'vertical')
plt.legend(['Jumlah Kasus','Jumlah Sembuh','Jumlah Meninggal'])
plt.title('Inforgrafis Covid-19 Di Indonesia Mulai Januari 2021')
plt.show()
