# %%
# Code cell 1
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium

# %%
# code cell 2
# This should be a local path
dataset_path = 'https://raw.githubusercontent.com/oBoii/Information-Management-5/master/08_netacad_san_fransico_labo/Map-Crime_Incidents-Previous_Three_Months.csv'

# read the original dataset (in comma separated values format) into a DataFrame
SF = pd.read_csv(dataset_path)
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
SF.head()
# Out:
#    IncidntNum       Category                        Descript DayOfWeek  \
# 0         NaN  LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 2         NaN  LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO    Sunday
# 3         NaN  DRUG/NARCOTIC  POSSESSION OF METH-AMPHETAMINE    Sunday
# 4         NaN  DRUG/NARCOTIC           POSSESSION OF COCAINE    Sunday
#
#                            Date   Time PdDistrict      Resolution  \
# 0  08/31/2014 07:00:00 AM +0000  20:30    CENTRAL            NONE
# 1  08/31/2014 07:00:00 AM +0000  14:30    CENTRAL            NONE
# 2  08/31/2014 07:00:00 AM +0000  11:30    CENTRAL            NONE
# 3  08/31/2014 07:00:00 AM +0000  17:49    MISSION  ARREST, BOOKED
# 4  08/31/2014 07:00:00 AM +0000  18:05   NORTHERN  ARREST, BOOKED
#
#                     Address           X          Y  \
# 0   HYDE ST / CALIFORNIA ST -122.417393  37.790974
# ...

# %%
pd.set_option('display.max_rows', 10) #Visualize 10 rows 
SF
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
SF.columns
# Out:
# Index(['IncidntNum', 'Category', 'Descript', 'DayOfWeek', 'Date', 'Time',
#        'PdDistrict', 'Resolution', 'Address', 'X', 'Y', 'Location'],
#       dtype='object')

# %%
len(SF)
# Out:
# 30760

# %%
# Code cell 7
SF['Month'] = SF['Date'].apply(lambda row: int(row[0:2]))
SF['Day'] = SF['Date'].apply(lambda row: int(row[3:5]))

# %%
# Code cell 8
print(SF['Month'][0:2])
print(SF['Day'][0:2])
# Out:
# 0    8
# 1    8
# Name: Month, dtype: int64
# 0    31
# 1    31
# Name: Day, dtype: int64

# %%
# Code cell 9
print(type(SF['Month'][0]))
# Out:
# <class 'numpy.int64'>

# %%
# Code cell 10
del SF['IncidntNum']

# %%
# Code cell 11
SF.drop('Location', axis=1, inplace=True )

# %%
# Code cell 12
SF.columns
# Out:
# Index(['Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y', 'Month', 'Day'],
#       dtype='object')

# %%
# Code cell 13
CountCategory = SF['Category'].value_counts()
print(CountCategory)
# Out:
# LARCENY/THEFT                 8205
# OTHER OFFENSES                4004
# NON-CRIMINAL                  3653
# ASSAULT                       2518
# VEHICLE THEFT                 1885
#                               ...
# SEX OFFENSES, NON FORCIBLE       5
# BAD CHECKS                       3
# GAMBLING                         1
# BRIBERY                          1
# PORNOGRAPHY/OBSCENE MAT          1
# Name: Category, Length: 36, dtype: int64

# %%
# Code cell 14
SF['Category'].value_counts(ascending=True)
# Out:
# BRIBERY                          1
# GAMBLING                         1
# PORNOGRAPHY/OBSCENE MAT          1
# BAD CHECKS                       3
# SEX OFFENSES, NON FORCIBLE       5
#                               ...
# VEHICLE THEFT                 1885
# ASSAULT                       2518
# NON-CRIMINAL                  3653
# OTHER OFFENSES                4004
# LARCENY/THEFT                 8205
# Name: Category, Length: 36, dtype: int64

# %%
# Code cell 15
print(SF['Category'].value_counts(ascending=True))
# Out:
# BRIBERY                          1
# GAMBLING                         1
# PORNOGRAPHY/OBSCENE MAT          1
# BAD CHECKS                       3
# SEX OFFENSES, NON FORCIBLE       5
#                               ...
# VEHICLE THEFT                 1885
# ASSAULT                       2518
# NON-CRIMINAL                  3653
# OTHER OFFENSES                4004
# LARCENY/THEFT                 8205
# Name: Category, Length: 36, dtype: int64

# %%
# code cell 16
# Possible code for the challenge question
print(SF['PdDistrict'].value_counts(ascending=True))
# Out:
# RICHMOND      1622
# PARK          1800
# TARAVAL       2038
# TENDERLOIN    2449
# INGLESIDE     2613
# BAYVIEW       2970
# NORTHERN      3205
# CENTRAL       3867
# MISSION       4011
# SOUTHERN      6185
# Name: PdDistrict, dtype: int64

# %%
# Code cell 17
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimes
# Out:
#                          Category  \
# 0                   LARCENY/THEFT
# 1                   LARCENY/THEFT
# 2                   LARCENY/THEFT
# 3                   DRUG/NARCOTIC
# 4                   DRUG/NARCOTIC
# ...                           ...
# 9715                 NON-CRIMINAL
# 9716               OTHER OFFENSES
# 9717                      ASSAULT
# 9718  DRIVING UNDER THE INFLUENCE
# 9719       SEX OFFENSES, FORCIBLE
#
#                                           Descript DayOfWeek  \
# 0                   GRAND THEFT FROM UNLOCKED AUTO    Sunday
# 1                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 2                     GRAND THEFT FROM LOCKED AUTO    Sunday
# 3                   POSSESSION OF METH-AMPHETAMINE    Sunday
# 4                            POSSESSION OF COCAINE    Sunday
# ...                                            ...       ...
# 9715                  AIDED CASE, MENTAL DISTURBED    Friday
# ...

# %%
# code cell 18
# Possible code for the question: How many burglaries were reported in the month of August?
AugustCrimes = SF[SF['Month'] == 8]
AugustCrimesB = SF[SF['Category'] == 'BURGLARY']
len(AugustCrimesB)
# Out:
# 1257

# %%
# Code cell 19
Crime0704 = SF.query('Month == 7 and Day == 4')
Crime0704
# Out:
#              Category                                          Descript  \
# 19087   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19088   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19089        BURGLARY  BURGLARY,RESIDENCE UNDER CONSTRT, FORCIBLE ENTRY
# 19090    NON-CRIMINAL                                     LOST PROPERTY
# 19091         ASSAULT                                           BATTERY
# ...               ...                                               ...
# 19423   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19424  OTHER OFFENSES                         LOST/STOLEN LICENSE PLATE
# 19425   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19426   LARCENY/THEFT                      GRAND THEFT FROM LOCKED AUTO
# 19427   LARCENY/THEFT                           PETTY THEFT OF PROPERTY
#
#       DayOfWeek                          Date   Time PdDistrict Resolution  \
# ...

# %%
# Code cell 20
SF.columns
# Out:
# Index(['Category', 'Descript', 'DayOfWeek', 'Date', 'Time', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y', 'Month', 'Day'],
#       dtype='object')

# %%
# Code cell 21
plt.plot(SF['X'],SF['Y'], 'ro')
plt.show()

# %%
# Code cell 22
pd_districts = np.unique(SF['PdDistrict'])
pd_districts_levels = dict(zip(pd_districts, range(len(pd_districts))))
pd_districts_levels
# Out:
# {'BAYVIEW': 0,
#  'CENTRAL': 1,
#  'INGLESIDE': 2,
#  'MISSION': 3,
#  'NORTHERN': 4,
#  'PARK': 5,
#  'RICHMOND': 6,
#  'SOUTHERN': 7,
#  'TARAVAL': 8,
#  'TENDERLOIN': 9}

# %%
# Code cell 23
SF['PdDistrictCode'] = SF['PdDistrict'].apply(lambda row: pd_districts_levels[row])

# %%
# Code cell 24
plt.scatter(SF['X'], SF['Y'], c=SF['PdDistrictCode'])
plt.show()

# %%
# Code cell 25
from matplotlib import colors
districts = np.unique(SF['PdDistrict'])
print(list(colors.cnames.values())[0:len(districts)])
# Out:
# ['#F0F8FF', '#FAEBD7', '#00FFFF', '#7FFFD4', '#F0FFFF', '#F5F5DC', '#FFE4C4', '#000000', '#FFEBCD', '#0000FF']

# %%
# Code cell 26
color_dict = dict(zip(districts, list(colors.cnames.values())[0:-1:len(districts)])) 
color_dict
# Out:
# {'BAYVIEW': '#F0F8FF',
#  'CENTRAL': '#8A2BE2',
#  'INGLESIDE': '#00FFFF',
#  'MISSION': '#FF8C00',
#  'NORTHERN': '#FF1493',
#  'PARK': '#F8F8FF',
#  'RICHMOND': '#4B0082',
#  'SOUTHERN': '#FAFAD2',
#  'TARAVAL': '#B0C4DE',
#  'TENDERLOIN': '#9370DB'}

# %%
# Code cell 27
# Create map
map_osm = folium.Map(location=[SF['Y'].mean(), SF['X'].mean()], zoom_start = 12)
plotEvery = 50
obs = list(zip( SF['Y'], SF['X'], SF['PdDistrict'])) 

for el in obs[0:-1:plotEvery]: 
    
    folium.CircleMarker(el[0:2], color=color_dict[el[2]], fill_color=el[2],radius=10).add_to(map_osm)

# %%
# Code cell 28
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
crimes = pd.read_csv("https://raw.githubusercontent.com/oBoii/Information-Management-5/master/08_netacad_san_fransico_labo/Map-Crime_Incidents-Previous_Three_Months.csv")

# %%
crimes
# Out:
#        IncidntNum        Category                               Descript  \
# 0             NaN   LARCENY/THEFT         GRAND THEFT FROM UNLOCKED AUTO
# 1             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 2             NaN   LARCENY/THEFT           GRAND THEFT FROM LOCKED AUTO
# 3             NaN   DRUG/NARCOTIC         POSSESSION OF METH-AMPHETAMINE
# 4             NaN   DRUG/NARCOTIC                  POSSESSION OF COCAINE
# ...           ...             ...                                    ...
# 30755         NaN   LARCENY/THEFT                PETTY THEFT SHOPLIFTING
# 30756         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
# 30757         NaN         ASSAULT                                BATTERY
# 30758         NaN         ASSAULT         ASSAULT WITH CAUSTIC CHEMICALS
# 30759         NaN  OTHER OFFENSES  DRIVERS LICENSE, SUSPENDED OR REVOKED
#
#       DayOfWeek                          Date   Time  PdDistrict  \
# ...

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

sns.set_palette("Set2")
sns.set_style("ticks")
crimes_missing = pd.DataFrame(crimes.isnull().mean()*100, columns=["Missing Values %"])
crimes_missing
# Out:
#             Missing Values %
# IncidntNum             100.0
# Category                 0.0
# Descript                 0.0
# DayOfWeek                0.0
# Date                     0.0
# ...                      ...
# Resolution               0.0
# Address                  0.0
# X                        0.0
# Y                        0.0
# Location                 0.0
#
# [12 rows x 1 columns]

# %%
crimes_original = crimes.copy()
crimes_original["Date"] = pd.to_datetime(crimes["Date"]).dt.strftime('%Y-%m-%d %H:%M:%S')
crimes_original.set_index(keys=crimes_original["Date"], inplace=True)
crimes_original.drop(columns=["Date"], inplace=True)

# %%
crimes.drop(columns=["Category", "Descript", "Resolution", "Address", "X", "Y","IncidntNum"], inplace=True)

# %%
# crimes['Date'] = pd.to_datetime(crimes['Date']).dt.strftime('%Y-%m-%d %H:%M:%S')
# # crimes['Date'] = pd.to_datetime(crimes['Date'])
# crimes = crimes.set_index('Date') 
crimes["Date"] = pd.to_datetime(crimes["Date"]).dt.date

# %%
crimes.head()
# Out:
#   DayOfWeek        Date   Time PdDistrict  \
# 0    Sunday  2014-08-31  20:30    CENTRAL
# 1    Sunday  2014-08-31  14:30    CENTRAL
# 2    Sunday  2014-08-31  11:30    CENTRAL
# 3    Sunday  2014-08-31  17:49    MISSION
# 4    Sunday  2014-08-31  18:05   NORTHERN
#
#                                 Location
# 0  (37.7909741243888, -122.417392830334)
# 1  (37.7963018736036, -122.404417620748)
# 2  (37.7894347630337, -122.406958660602)
# 3  (37.7650501214965, -122.419671780296)
# 4  (37.7851670875814, -122.417903977564)

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="DayOfWeek", data=crimes, order=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
plt.title("Crimes by Day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Crimes")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="PdDistrict", data=crimes_original, order=crimes_original["PdDistrict"].value_counts().index)
plt.xlabel("Police Department District")
plt.ylabel("Crimes")
plt.title("Crimes by Police Department District")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Resolution", data=crimes_original, order=crimes_original["Resolution"].value_counts().index)
plt.title("Crimes Resolutions")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="Category", data=crimes_original, order=crimes_original["Category"].value_counts().index)
plt.xlabel("Category Crimes")
plt.ylabel("Crimes")
plt.title("Category Crimes")
plt.xticks(rotation=90)
plt.show()

# %%
y = crimes_original['Category'].value_counts().head(10)
    
plt.rcParams['figure.figsize'] = (15, 15)
plt.style.use('fivethirtyeight')

color = plt.cm.magma(np.linspace(0, 1, 15))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color)
plt.title('Tree Map for Top 25 Crimes', fontsize = 20)

plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (15, 15)
plt.style.use('fast')

wc = WordCloud(background_color = 'orange', width = 1500, height = 1500).generate(str(crimes_original['Descript']))
plt.title('Description of the Crime', fontsize = 20)

plt.imshow(wc)
plt.axis('off')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('seaborn')

color = plt.cm.spring(np.linspace(0, 1, 15))
crimes_original['PdDistrict'].value_counts().plot.bar(color = color, figsize = (15, 10))

plt.title('District with Most Crime',fontsize = 30)

plt.xticks(rotation = 90)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('seaborn')

color = plt.cm.ocean(np.linspace(0, 1, 15))
crimes_original['Address'].value_counts().head(15).plot.bar(color = color, figsize = (15, 10))

plt.title('Top 15 Regions in Crime',fontsize = 20)

plt.xticks(rotation = 90)
plt.show()
